# %%
from skimage import data, filter, color
from skimage.transform import hough_ellipse
from skimage.draw import ellipse_perimeter

# %%
from PIL import Image
from IPython.core import display
from io import BytesIO

def display_pil_image(im):
    """displayhook function for PIL Images, rendered as PNG"""
    b = BytesIO()
    im.save(b, format='png')
    data = b.getvalue()

    ip_img = display.Image(data=data, format='png', embed=True)
    return ip_img._repr_png_()

def display_numpy_image(im, cmap="Greys"):
    imshow(im, cmap=cmap)
    xticks([])
    yticks([])   

# register display func with PNG formatter:
png_formatter = get_ipython().display_formatter.formatters['image/png']
png_formatter.for_type(Image.Image, display_pil_image);

# %%
img = Image.open("sunflower.jpg")
print img.mode, img.size
img
# Out:
# RGB (275, 183)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x15549388>

# %% [markdown]
# We now follow this [example](http://scikit-image.org/docs/dev/auto_examples/plot_circular_elliptical_hough_transform.html).
#
# Load picture, convert to grayscale:

# %%
image_rgb = data.coffee()[0:220, 160:420] # array(img)
image_gray = color.rgb2gray(image_rgb)
display_numpy_image(image_gray)

# %% [markdown]
# Detect edges:

# %%
edges = filter.canny(image_gray, sigma=2.0,
                     low_threshold=0.55, high_threshold=0.8)
display_numpy_image(edges)

# %% [markdown]
# Perform a Hough Transform:
#
# - The accuracy corresponds to the bin size of a major axis.
# - The value is chosen in order to get a single high accumulator.
# - The threshold eliminates low accumulators

# %%
result = hough_ellipse(edges, accuracy=20, threshold=250,
                       min_size=100, max_size=120)
result.sort(order='accumulator')
print "Result:", result
# Out:
# Result: [(252L, 112.0, 130.0, 116.61903789690601, 94.42986815621421, 1.6662500411276109)
#  (253L, 112.5, 130.0, 116.61903789690601, 94.26690829766297, 1.698440783161212)
#  (260L, 112.0, 130.5, 116.61903789690601, 94.47883360838024, 1.6715181647839699)
#  (270L, 112.5, 130.0, 116.61903789690601, 94.14483522743029, 1.6879050713617607)
#  (274L, 112.5, 130.5, 116.61903789690601, 94.88150504708491, 1.6605020158119568)
#  (276L, 112.5, 130.5, 116.61903789690601, 94.20456464524423, 1.6931763403676956)
#  (281L, 112.5, 130.5, 116.61903789690601, 94.08772502298055, 1.682627256350016)]

# %% [markdown]
# Estimated parameters for the ellipse

# %%
best = result[-1]
yc = int(best[1])
xc = int(best[2])
a = int(best[3])
b = int(best[4])
orientation = best[5]

# %% [markdown]
# Draw the ellipse on the original image

# %%
cy, cx = ellipse_perimeter(yc, xc, a, b, orientation)
image_rgb[cy, cx] = (0, 0, 255)

# %% [markdown]
# Draw the edge (white) and the resulting ellipse (red)

# %%
edges = color.gray2rgb(edges)
edges[cy, cx] = (250, 0, 0)

# %% [markdown]
# Plot the result

# %%
fig2, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(8, 4))

ax1.set_title('Original picture')
ax1.imshow(image_rgb)

ax2.set_title('Edge (white) and result (red)')
ax2.imshow(edges)
