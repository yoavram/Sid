# %%
from skimage import data, filter, color
from skimage.transform import hough_ellipse
from skimage.draw import ellipse_perimeter

# %%
from PIL import Image
from IPython.core import display
from io import BytesIO

def display_pil_image(im):
    """displayhook function for PIL Images, rendered as PNG"""
    b = BytesIO()
    im.save(b, format='png')
    data = b.getvalue()

    ip_img = display.Image(data=data, format='png', embed=True)
    return ip_img._repr_png_()

def display_numpy_image(im, cmap="Greys"):
    imshow(im, cmap=cmap)
    xticks([])
    yticks([])   

# register display func with PNG formatter:
png_formatter = get_ipython().display_formatter.formatters['image/png']
png_formatter.for_type(Image.Image, display_pil_image);

# %%
256/10.
# Out:
# 25.6

# %%
#img = Image.open("sunflower.jpg")
img = Image.open("Tv4_downsample.jpg")
print img.mode, img.size
img
# Out:
# RGB (510, 384)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x384 at 0x182A9AC8>

# %% [markdown]
# Load picture, convert to grayscale:

# %%
image_rgb = array(img)
image_gray = 255-color.rgb2gray(image_rgb)
display_numpy_image(image_gray)

# %% [markdown]
# ## Otsu segmentation

# %%
thresh = filter.threshold_otsu(image_gray)
mask = image_gray >= thresh
display_numpy_image(mask)

# %% [markdown]
# ## Edge detection

# %%
edges = filter.canny(mask, sigma=1,
                     low_threshold=0.55, high_threshold=0.8)
display_numpy_image(edges)

# %%
edges = filter.rank.maximum(edges, square(3))
display_numpy_image(edges)

# %%
sum(edges==255),sum(edges==0)
# Out:
# (18052, 177788)

# %% [markdown]
# ## Connected components
# http://scipy-lectures.github.io/advanced/image_processing/#measuring-objects-properties-ndimage-measurements

# %%
from scipy import ndimage

# %%
display_numpy_image(image_gray)

# %%
im = ndimage.gaussian_filter(image_gray, sigma=256/40.)
display_numpy_image(im)

# %%
mask = im > im.mean()
mask = ~mask
display_numpy_image(mask)

# %%
label_im, nb_labels = ndimage.label(mask)
print nb_labels # how many regions?
display_numpy_image(label_im, cmap=plt.cm.spectral)
# Out:
# 2

# %%
sizes = ndimage.sum(mask, label_im, range(nb_labels + 1))
mean_vals = ndimage.sum(im, label_im, range(1, nb_labels + 1))
print sizes
print mean_vals
# Out:
# [     0.  31624.  31252.]
# [ 8048464.611  7959187.87 ]

# %%
slice_x,slice_y = ndimage.find_objects(label_im==1)[0]
img1 = image_rgb[slice_x, slice_y]
display_numpy_image(img1)

# %%
slice_x,slice_y = ndimage.find_objects(label_im==2)[0]
img2 = image_rgb[slice_x, slice_y]
display_numpy_image(img2)

# %%
img1 = 255-color.rgb2gray(img1)
display_numpy_image(img1)

# %%
img2 = 255-color.rgb2gray(img2)
display_numpy_image(img2)

# %%
img1_edges = img1.copy()
display_numpy_image(img1_edges)

# %%
img2_edges = img2.copy()
display_numpy_image(img2_edges)

# %%
th = img1_edges.mean()
print "Threshold:", th
display_numpy_image(img1_edges <= th)
# Out:
# Threshold: 254.635644849

# %%
label_im, nb_labels = ndimage.label(img1_edges <= th)
print nb_labels # how many regions?
display_numpy_image(label_im, cmap=plt.cm.spectral)
sizes = ndimage.sum(255-img1_edges, label_im, range(nb_labels + 1))
print "%.2g" % sum(sizes[1:])
# Out:
# 23
# 1.4e+04

# %%
th = img2_edges.mean()
print "Threshold:", th
display_numpy_image(img2_edges <= th)
# Out:
# Threshold: 254.758218051

# %%
label_im, nb_labels = ndimage.label(img2_edges <= th)
print nb_labels # how many regions?
display_numpy_image(label_im, cmap=plt.cm.spectral)
sizes = ndimage.sum(255-img2_edges, label_im, range(nb_labels + 1))
print "%.2g" % sum(sizes[1:])
# Out:
# 200
# 8.8e+03
